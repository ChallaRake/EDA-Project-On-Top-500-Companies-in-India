# %%
import requests
from bs4 import BeautifulSoup
import re
import numpy as np
import pandas as pd

# %%
from selenium import webdriver
from selenium.webdriver.edge.service import Service as EdgeService
from selenium.webdriver.edge.options import Options as EdgeOptions
from webdriver_manager.microsoft import EdgeChromiumDriverManager
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time
import re

# %%
Title = []
Ratings = []
Reviews  = []
C_Type = []
Salaries = []
Interviews = []
Jobs = []
Year_Founded = []
for i in range(1,3):
    url = f"https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav&page={i}"
    service = EdgeService(EdgeChromiumDriverManager().install())
    options = EdgeOptions()
    driver = webdriver.Edge(service=service, options=options)
    driver.get(url)
    print(url)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    company = soup.find_all("div", class_ = "companyCardWrapper")

    for i in company:
        linkreg = re.findall(r'<meta\scontent="(https.+)"\sitemprop="url"',str(i))
        service = EdgeService(EdgeChromiumDriverManager().install())
        options = EdgeOptions()
        driver = webdriver.Edge(service=service, options=options)
        driver.get(linkreg[0])
        #print(linkreg[0])
        html = driver.page_source
        soup1 = BeautifulSoup(html, "html.parser")
        company2 = soup1.find_all("div",class_ = "bg-white flex flex-col")
        
        for j in company2:
            title = j.find("h1", class_ = "text-xl font-pn-700 text-primary-text mr-1 md:text-2xl break-word")
            titreg = re.findall(r">(.+)<",str(title))
            #titreg = title
            if titreg:
                print(titreg)
                Title.append(titreg[0])
            else:
                Title.append(np.nan)
        driver.quit()
        
    driver.quit()
# Out:
# https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav&page=1
# ['TCS']
# ['Accenture']
# ['Wipro']
# ['Cognizant']
# ['HDFC Bank']
# ['Infosys']
# ['HCLTech']
# ['Tech Mahindra']
# ['Genpact']
# ['Teleperformance']
# ['Axis Bank']
# ['Amazon']
# ['Jio']
# ['Reliance Retail']
# ['IBM']
# ['LTIMindtree']
# https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav&page=2

# %%
Title = []
Ratings = []
Reviews  = []
C_Type = []
Salaries = []
Interviews = []
Jobs = []
Year_Founded = []
for i in range(1,3):
    url = f"https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav&page={i}"
    service = EdgeService(EdgeChromiumDriverManager().install())
    options = EdgeOptions()
    driver = webdriver.Edge(service=service, options=options)
    driver.get(url)
    print(url)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    company = soup.find_all("div", class_ = "companyCardWrapper")

    for i in company:
        title = i.find("h2", class_ = "companyCardWrapper__companyName")
        titreg = re.findall(r"\s+(.+)\s+",title.text)
        if titreg:
            Title.append(titreg[0])
        else:
            Title.append(np.nan)

        rating = i.find("div", class_ = "rating_star_container")
        ratreg = re.findall(r"\s+(.+)",rating.text)
        if ratreg:
            Ratings.append(ratreg[0])
        else:
            Ratings.append(np.nan)

        reviews = i.find("span", class_ = "companyCardWrapper__companyRatingCount")
        revreg = re.findall(r"\((.+)\)",reviews.text)
        if revreg:
            Reviews.append(revreg[0])
        else:
            Reviews.append(np.nan)

        ctype = i.find("span", class_ = "companyCardWrapper__interLinking")
        typreg = re.findall(r"\s+(.+)\s\|",ctype.text)
        if typreg:
            C_Type.append(typreg[0])
        else:
            C_Type.append(np.nan)

        salary = re.findall(r"Reviews(.+)\sSalaries",i.text)
        if salary:
            Salaries.append(salary[0])
        else:
            Salaries.append(np.nan)
            
        interview = re.findall(r"Salaries(.+)\sInter",i.text)
        if interview:
            Interviews.append(interview[0])
        else:
            Interviews.append(np.nan)

        job = re.findall(r"Interviews(.+)\sJobs",i.text)
        if job:
            Jobs.append(job[0])
        else:
            Jobs.append(np.nan)

        
        linkreg = re.findall(r'<meta\scontent="(https.+)"\sitemprop="url"',str(i))
        #service = EdgeService(EdgeChromiumDriverManager().install())
        #options = EdgeOptions()
        driver = webdriver.Edge(service=service, options=options)
        driver.get(linkreg[0])
        #print(linkreg)
        html = driver.page_source
        soup1 = BeautifulSoup(html, "html.parser")
        company2 = soup1.find_all("div",class_ = "bg-white flex flex-col")

        for j in company2:    
            yearreg = re.findall(r"Founded in(\d+)\s\(",j.text)
            if yearreg:
                print(yearreg)
                Year_Founded.append(yearreg[0])
            else:
                Year_Founded.append(np.nan)



            
        driver.quit()

        
            
    driver.quit()


# 59.1k Reviews5.9L Salaries8.3k Interviews9.1k Jobs7.4k Benefits39 Photos
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\webdriver_manager\core\file_manager.py:65, in FileManager.__extract_zip(self, archive_file, to_directory)
#      64 try:
# ---> 65     archive.extractall(to_directory)
#      66 except Exception as e:
#
# File ~\anaconda3\Lib\zipfile\__init__.py:1744, in ZipFile.extractall(self, path, members, pwd)
#    1743 for zipinfo in members:
# -> 1744     self._extract_member(zipinfo, path, pwd)
#
# File ~\anaconda3\Lib\zipfile\__init__.py:1801, in ZipFile._extract_member(self, member, targetpath, pwd)
#    1798     return targetpath
#    1800 with self.open(member, pwd=pwd) as source, \
# -> 1801      open(targetpath, "wb") as target:
#    1802     shutil.copyfileobj(source, target)
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\rake0\\.wdm\\drivers\\edgedriver\\win64\\135.0.3179.73\\msedgedriver.exe'
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[89], line 11
#       9 for i in range(1,3):
#      10     url = f"https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav&page={i}"
# ---> 11     service = EdgeService(EdgeChromiumDriverManager().install())
#      12     options = EdgeOptions()
#      13     driver = webdriver.Edge(service=service, options=options)
#
# File ~\anaconda3\Lib\site-packages\webdriver_manager\microsoft.py:73, in EdgeChromiumDriverManager.install(self)
#      72 def install(self) -> str:
# ---> 73     driver_path = self._get_driver_binary_path(self.driver)
#      74     os.chmod(driver_path, 0o755)
#      75     return driver_path
#
# File ~\anaconda3\Lib\site-packages\webdriver_manager\core\manager.py:41, in DriverManager._get_driver_binary_path(self, driver)
#      39 os_type = self.get_os_type()
#      40 file = self._download_manager.download_file(driver.get_driver_download_url(os_type))
# ---> 41 binary_path = self._cache_manager.save_file_to_cache(driver, file)
#      42 return binary_path
#
# File ~\anaconda3\Lib\site-packages\webdriver_manager\core\driver_cache.py:54, in DriverCacheManager.save_file_to_cache(self, driver, file)
#      52 path = self.__get_path(driver)
#      53 archive = self.save_archive_file(file, path)
# ---> 54 files = self.unpack_archive(archive, path)
#      55 binary = self.__get_binary(files, driver.get_name())
#      56 binary_path = os.path.join(path, binary)
#
# File ~\anaconda3\Lib\site-packages\webdriver_manager\core\driver_cache.py:49, in DriverCacheManager.unpack_archive(self, archive, path)
#      48 def unpack_archive(self, archive, path):
# ---> 49     return self._file_manager.unpack_archive(archive, path)
#
# File ~\anaconda3\Lib\site-packages\webdriver_manager\core\file_manager.py:57, in FileManager.unpack_archive(self, archive_file, target_dir)
#      55 file_path = archive_file.file_path
#      56 if file_path.endswith(".zip"):
# ---> 57     return self.__extract_zip(archive_file, target_dir)
#      58 elif file_path.endswith(".tar.gz"):
#      59     return self.__extract_tar_file(archive_file, target_dir)
#
# File ~\anaconda3\Lib\site-packages\webdriver_manager\core\file_manager.py:81, in FileManager.__extract_zip(self, archive_file, to_directory)
#      79         source = os.path.join(full_file_path, file_name)
#      80         destination = os.path.join(to_directory, file_name)
# ---> 81         os.replace(source, destination)
#      82         file_names.append(file_name)
#      83 return sorted(file_names, key=lambda x: x.lower())
#
# PermissionError: [WinError 5] Access is denied: 'C:\\Users\\rake0\\.wdm\\drivers\\edgedriver\\win64\\135.0.3179.73\\Driver_Notes\\' -> 'C:\\Users\\rake0\\.wdm\\drivers\\edgedriver\\win64\\135.0.3179.73\\'

# %%
len(Year_Founded)
# Out:
# 40

# %%
Year_Founded
# Out:
# [['1996'],
#  ['1989'],
#  ['1945'],
#  ['1994'],
#  ['1967'],
#  ['1994'],
#  ['1981'],
#  ['1994'],
#  ['1991'],
#  ['1986'],
#  ['1997'],
#  ['1978'],
#  ['1983'],
#  ['1993'],
#  ['1994'],
#  ['2018'],
#  ['2000'],
#  ['2006'],
#  ['1911'],
#  ['1997'],
#  ['2007'],
#  ['1938'],
#  ['1845'],
#  ['2003'],
#  ['1977'],
#  ['2011'],
#  ['2018'],
#  ['1952'],
#  ['1996'],
#  ['1945'],
#  ['1996'],
#  ['1994'],
#  ['2007'],
#  ['2002'],
#  ['2018'],
#  ['2017'],
#  ['2002'],
#  ['1945'],
#  ['2007'],
#  ['1880']]

# %%
for i in range(1,2):
    url = "https://www.ambitionbox.com/overview/ienergizer-overview"
    service = EdgeService(EdgeChromiumDriverManager().install())
    options = EdgeOptions()
    driver = webdriver.Edge(service=service, options=options)
    driver.get(url)
    print(url)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    company = soup.find_all("div", class_ = "bg-white flex flex-col")
    #print(company)
    for i in company:
        print(i.text)
        
    driver.quit()
driver.quit()
# Out:
# https://www.ambitionbox.com/overview/ienergizer-overview
# Premium EmployeriEnergizerWrite a ReviewFollow (25.1k)Compare4.6based on 23.4k ReviewsWhy join us23.4kReviews22.8kSalaries674Interviews200Jobs567Benefits27Photos6PostsCompany OverviewCompany LocationsAbout iEnergizer"Unlocking Potential, Unleashing Performance"2000Founded YearNoidaHeadquarters25,000+Company SizeDiscover enhanced operational efficiency through our premier BPO services seamlessly integrated with state-of-the-art IT solutions. Our focus on streamlining processes and enhancing productivity aims to support your business's success in navigating the complexities of the digital age. Experience excellence with us.read moreiEnergizer ReviewsRating 4.6Overall rating based on 23.4k reviews onAmbitionBoxFeaturedTrainee in Noida5.0 •  posted on 26 Nov 2021Likes:Job security work culture excellent Dislikes:TransportFeaturedDesktop Support Engineer in Noida sector 10Engineering - Hardware & Networks5.0 •  posted on 03 Nov 2021Likes:Because job security 100% sure so I like this company Dislikes:No any reasionFeaturedSenior Executive in NoidaOther5.0 •  posted on 26 Oct 2021Likes:Good work environment and culture. Teammates are supportive and the managment is transparent. There is a huge three cafeterias and gaming acarde for chilling. Company policies are good, appraisals are fair and they give
html = driver.page_source
soup = BeautifulSoup(html, "html.parser")
company = soup.find_all("div", class_ = "companyCardWrapper")
#year = company.find("div", class_ = "css-175oi2r gap-y-4 md:flex-row md:flex-wrap md:justify-start md:gap-y-[32px] md:gap-5")

if company:
    print(company.text)
    print("****"*30)
# Out:
# https://www.ambitionbox.com/overview/infosys-overview
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 10
#       8 soup = BeautifulSoup(html, "html.parser")
#       9 company = soup.find_all("div", class_ = "companyCardWrapper")
# ---> 10 year = company.find("div", class_ = "css-175oi2r gap-y-4 md:flex-row md:flex-wrap md:justify-start md:gap-y-[32px] md:gap-5")
#      12 if year:
#      13     print(year.text)
#
# File ~\anaconda3\Lib\site-packages\bs4\element.py:2433, in ResultSet.__getattr__(self, key)
#    2431 def __getattr__(self, key):
#    2432     """Raise a helpful exception to explain a common code fix."""
# -> 2433     raise AttributeError(
#    2434         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2435     )
#
# AttributeError: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
import time

# %%
Title = []
Ratings = []
Reviews  = []
C_Type = []
Salaries = []
Interviews = []
Jobs = []
Year_Founded = []
C_Age = []
for i in range(1,3):
    url = f"https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav&page={i}"
    service = EdgeService(EdgeChromiumDriverManager().install())
    options = EdgeOptions()
    driver = webdriver.Edge(service=service, options=options)
    driver.get(url)
    print(url)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    company = soup.find_all("div", class_ = "companyCardWrapper")

    for i in company:
        title = i.find("h2", class_ = "companyCardWrapper__companyName")
        titreg = re.findall(r"\s+(.+)\s+",title.text)
        if titreg:
            Title.append(titreg[0])
        else:
            Title.append(np.nan)

        rating = i.find("div", class_ = "rating_star_container")
        ratreg = re.findall(r"\s+(.+)",rating.text)
        if ratreg:
            Ratings.append(ratreg[0])
        else:
            Ratings.append(np.nan)

        reviews = i.find("span", class_ = "companyCardWrapper__companyRatingCount")
        revreg = re.findall(r"\((.+)\)",reviews.text)
        if revreg:
            Reviews.append(revreg[0])
        else:
            Reviews.append(np.nan)

        ctype = i.find("span", class_ = "companyCardWrapper__interLinking")
        typreg = re.findall(r"\s+(.+)\s\|",ctype.text)
        if typreg:
            C_Type.append(typreg[0])
        else:
            C_Type.append(np.nan)

        salary = re.findall(r"Reviews(.+)\sSalaries",i.text)
        if salary:
            Salaries.append(salary[0])
        else:
            Salaries.append(np.nan)
            
        interview = re.findall(r"Salaries(.+)\sInter",i.text)
        if interview:
            Interviews.append(interview[0])
        else:
            Interviews.append(np.nan)

        job = re.findall(r"Interviews(.+)\sJobs",i.text)
        if job:
            Jobs.append(job[0])
        else:
            Jobs.append(np.nan)

        
        linkreg = re.findall(r'<meta\scontent="(https.+)"\sitemprop="url"',str(i))
        #service = EdgeService(EdgeChromiumDriverManager().install())
        #options = EdgeOptions()
        driver = webdriver.Edge(service=service, options=options)
        driver.get(linkreg[0])
        time.sleep(5)
        #print(linkreg[0])
        html = driver.page_source
        soup1 = BeautifulSoup(html, "html.parser")
        company2 = soup1.find_all("div",class_ = "bg-white flex flex-col")

        for j in company2:
            print(j.text)
            print("******"*25)
# Out:
# https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav&
unlock₹1.5 L/yr - ₹7.5 L/yrProcess Associate(16.5k salaries)Unlock₹1 L/yr - ₹6.8 L/yrTCS Interview QuestionsView allInterview questions by designationSystem Engineer(1164)Software Developer(512)Software Engineer(461)Assistant System Engineer(389)Assistant System Engineer Trainee(375)IT Analyst(341)View all 9.5k interview experiences Top TCS interview questions and answersasked in System Engineer interviewQ1. Election Winner Determination In an ongoing election between two candi...read moreView answers (9) asked in Software Engineer interviewQ2. Find the Duplicate Number Problem Statement Given an integer array 'AR...read moreView answers (9) Get interview-ready with top interview questionsView all 6.2k questionsasked in Assistant System Engineer interviewQ3. Constellation Identification Problem Given a matrix named UNIVERSE wit...read moreView answers (4) asked in Software Developer interviewQ4. Palindromic Numbers Finder Given an integer 'N', your task is to ident...read moreView answers (3) asked in Assistant System Engineer Trainee interviewQ5. #include int main() { int any = ' ' * 10; printf("%d", any); return 0;...read moreView answers (3) TCS JobsView allPopular Designations TCS Hires forSAP SD ConsultantView 7 jobsJava Spring Boot DeveloperView 7 jobsSAP AbapView 6 jobsSAP Fico ConsultantView 6 jobsSalesView 5 jobsDot Net Fullstack DeveloperView 5 jobsJava DeveloperView 3 jobsSecurityView 3 jobsOracleView 3 jobsDeveloperView 3 jobsPopular Skills TCS Hires for JavaSAP SDSAP ABAPServicenowJava Spring BootSalesforceSAP FICOOracleSAP COWorkdayCurrent OpeningsMega Walkin Drive For Oracle EBS Finance ConsultantPune4 - 9 YrsNot DisclosedMega Walkin Drive in Pune - Sap CO ConsultantPune4 - 9 YrsNot DisclosedWalkin Drive in Pune - SAP SuccessFactorPune4 - 9 YrsNot DisclosedDirect WalkIn at Tcs Bangalore For Credit Analyst SpecialistBangalore / Bengaluru4 - 5 YrsNot DisclosedDirect WalkIn at Tcs Bangalore For Banking and Collateral SpecialistBangalore / Bengaluru4 - 5 Yrs₹ 4.5-7.4 LPATelecom BillingHyderabad / Secunderabad +13 - 5 YrsNot DisclosedTCS NewsView allXRPturbo ($XRT) Now Trading on Bitmart, Set To Host First AMA on Satoshi Club, Announces Liquid Staking & XRP Launchpad RolloutXRPTurbo ($XRT) has successfully launched on Bitmart Exchange, trading more than 30% above its listing price within hours.The XRT token is now trading on Bitmart under the XRT/USDT pair and is set to be listed on Coingecko and CMC soon.The XRPTurbo team will host their f ...
# ******************************************************************************************************************************************************
# Add office photosEmployer?Claim Account for FREEAccentureWrite a ReviewFollow (3L)Compare3.8based on 59.2k Reviews Video summaryProud winner of ABECA 2024 - AmbitionBox Employee Choice AwardsTop Rated Mega Company - 2024Top Rated Company for Women - 2024Top Rated IT/ITES Company - 2024About59.2kReviews5.9LSalaries8.4kInterviews8.8kJobs7.4kBenefits39Photos90PostsCompany OverviewAssociated CompaniesCompany LocationsWorking at AccentureCompany SummaryAccenture plc is an Irish-American, professional services company based in Dublin, specializing in information technology services and consulting.IT Services & ConsultingAnalytics & KPOSoftware ProductManagement ConsultingOverall Rating3.8/5based on 59.2k reviews3% above industry averageCritically rated forPromotionsKey Factors to Cons
://www.ambitionbox.com/list-of-companies?campaign=desktop_nav&page={i}"
    service = EdgeService(EdgeChromiumDriverManager().install())
    options = EdgeOptions()
    driver = webdriver.Edge(service=service, options=options)
    driver.get(url)
    print(url)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    company = soup.find_all("div", class_ = "companyCardWrapper")

    for i in company:
        title = i.find("h2", class_ = "companyCardWrapper__companyName")
        titreg = re.findall(r"\s+(.+)\s+",title.text)
        if titreg:
            Title.append(titreg[0])
        else:
            Title.append(np.nan)

        rating = i.find("div", class_ = "rating_star_container")
        ratreg = re.findall(r"\s+(.+)",rating.text)
        if ratreg:
            Ratings.append(ratreg[0])
        else:
            Ratings.append(np.nan)

        reviews = i.find("span", class_ = "companyCardWrapper__companyRatingCount")
        revreg = re.findall(r"\((.+)\)",reviews.text)
        if revreg:
            Reviews.append(revreg[0])
        else:
            Reviews.append(np.nan)

        ctype = i.find("span", class_ = "companyCardWrapper__interLinking")
        typreg = re.findall(r"\s+(.+)\s\|",ctype.text)
        if typreg:
            C_Type.append(typreg[0])
        else:
            C_Type.append(np.nan)

        salary = re.findall(r"Reviews(.+)\sSalaries",i.text)
        if salary:
            Salaries.append(salary[0])
        else:
            Salaries.append(np.nan)
            
        interview = re.findall(r"Salaries(.+)\sInter",i.text)
        if interview:
            Interviews.append(interview[0])
        else:
            Interviews.append(np.nan)

        job = re.findall(r"Interviews(.+)\sJobs",i.text)
        if job:
            Jobs.append(job[0])
        else:
            Jobs.append(np.nan)

        
        linkreg = re.findall(r'<meta\scontent="(https.+)"\sitemprop="url"',str(i))
        #service = EdgeService(EdgeChromiumDriverManager().install())
        #options = EdgeOptions()
        driver = webdriver.Edge(service=service, options=options)
        driver.get(linkreg[0])
        time.sleep(3)
        #print(linkreg[0])
        html = driver.page_source
        soup1 = BeautifulSoup(html, "html.parser")
        company2 = soup1.find_all("div",class_ = "bg-white flex flex-col")

        for j in company2:
            webreg = re.findall(r"Website(.+)\s?(?:Primary|Social|Company\scontact\sno)",j.text)
            if webreg:
                print(webreg)
                Websites.append(webreg[0])
            else:
                Websites.append(np.nan)
        driver.quit()
    driver.quit()
# Out:
# https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav&page=1
# ['tcs.com']
# ['accenture.com']
# ['careers.wipro.com']
# ['cognizant.com']
# ['capgemini.com']
# ['hdfcbank.com']
# ['infosys.com ']
# ['icicibank.com']
# ['hcltech.com ']
# ['techmahindra.com']
# ['genpact.com']
# ['teleperformance.com']
# ['concentrix.com']
# ['axisbank.com ']
# ['amazon.jobs']
# ['jio.com']
# ['ienergizer.com Company contact no.8588894888 E-mailinfo@iEnergizer.com ']
# ['relianceretail.com']
# ['ibm.com']
# ['ltimindtree.com']
# https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav&page=2
# ['hdbfs.com']
# ['larsentoubro.com']
# ['www2.deloitte.com']
# ['kotak.com']
# ['ril.com']
# ['byjus.com']
# ['myvi.in']
# ['airtel.in']
# ['wns.com']
# ['tatamotors.com']
# ['aubank.in']
# ['indusind.com']
# ['flipkart.com']
# ['ey.com']
# ['idfcfirstbank.com ']
# ['dxc.com']
# ['infosysbpm.com']
# ['mahindra.com']
# ['bajajfinserv.in']
# ['pwc.com']

# %%
len(Websites)
# Out:
# 40
