# %%
import requests
from bs4 import BeautifulSoup
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Companies_500.csv")
df
# Out:
#      Unnamed: 0                        Title Reviews  Ratings  \
# 0             0                          TCS   93.7k      3.7
# 1             1                    Accenture   59.3k      3.8
# 2             2                        Wipro   55.1k      3.7
# 3             3                    Cognizant   52.4k      3.7
# 4             4                    Capgemini   43.9k      3.7
# ..          ...                          ...     ...      ...
# 495         495  Infinite Computer Solutions    1.6k      3.4
# 496         496                      Philips    1.6k      3.8
# 497         497              Dr Lal PathLabs    1.6k      4.2
# 498         498         Honeywell Automation    1.6k      3.8
# 499         499                Nuvoco Vistas    1.6k      4.1
#
#                           Company Type Salaries Total Interviews Total Jobs  \
# 0             IT Services & Consulting     8.9L            10.7k        177
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        500 non-null    int64
#  1   Title             500 non-null    object
#  2   Reviews           500 non-null    object
#  3   Ratings           500 non-null    float64
#  4   Company Type      478 non-null    object
#  5   Salaries          500 non-null    object
#  6   Total Interviews  500 non-null    object
#  7   Total Jobs        500 non-null    object
#  8   Founded Year      485 non-null    float64
#  9   Company Age       485 non-null    float64
#  10  Websites          500 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 43.1+ KB

# %%
df.drop(["Unnamed: 0"],axis=1,inplace=True)
df
# Out:
#                            Title Reviews  Ratings  \
# 0                            TCS   93.7k      3.7
# 1                      Accenture   59.3k      3.8
# 2                          Wipro   55.1k      3.7
# 3                      Cognizant   52.4k      3.7
# 4                      Capgemini   43.9k      3.7
# ..                           ...     ...      ...
# 495  Infinite Computer Solutions    1.6k      3.4
# 496                      Philips    1.6k      3.8
# 497              Dr Lal PathLabs    1.6k      4.2
# 498         Honeywell Automation    1.6k      3.8
# 499                Nuvoco Vistas    1.6k      4.1
#
#                           Company Type Salaries Total Interviews Total Jobs  \
# 0             IT Services & Consulting     8.9L            10.7k        177
# 1             IT Services & Consulting     5.9L             8.4k       8.8k
# 2             IT Services & Consulting     4.5L             5.8k       4.1k
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             500 non-null    object
#  1   Reviews           500 non-null    object
#  2   Ratings           500 non-null    float64
#  3   Company Type      478 non-null    object
#  4   Salaries          500 non-null    object
#  5   Total Interviews  500 non-null    object
#  6   Total Jobs        500 non-null    object
#  7   Founded Year      485 non-null    float64
#  8   Company Age       485 non-null    float64
#  9   Websites          500 non-null    object
# dtypes: float64(3), object(7)
# memory usage: 39.2+ KB

# %%
df['Reviews'].unique()
# Out:
# array(['93.7k', '59.3k', '55.1k', '52.4k', '43.9k', '41.3k', '41.1k',
#        '39.5k', '37.8k', '36.6k', '33k', '31k', '27.4k', '26.5k', '26.2k',
#        '24.3k', '23.4k', '23.2k', '21.9k', '21.1k', '19.4k', '18.5k',
#        '17.7k', '16.7k', '16.3k', '15.8k', '14.2k', '12.5k', '12.3k',
#        '12k', '11.5k', '11.1k', '11.3k', '10.8k', '10.4k', '10.2k',
#        '10.1k', '9.8k', '9.6k', '9.5k', '9.1k', '8.7k', '8.1k', '7.9k',
#        '7.7k', '7.5k', '7.4k', '7.3k', '7.1k', '7k', '6.7k', '6.5k',
#        '6.4k', '6.3k', '6.2k', '6.1k', '6k', '5.8k', '5.7k', '5.6k',
#        '5.5k', '5.4k', '5.3k', '5.2k', '5.1k', '5k', '4.9k', '4.8k',
#        '4.7k', '4.6k', '4.5k', '4.4k', '4.3k', '4.2k', '4.1k', '4k',
#        '3.9k', '3.8k', '3.7k', '3.6k', '3.5k', '3.4k', '3.3k', '3.2k',
#        '3.1k', '3k', '2.9k', '2.8k', '2.7k', '2.6k', '2.5k', '2.4k',
#        '2.3k', '2.2k', '2.1k', '2k', '1.4k', '1.9k', '1.8k', '1.7k',
#        '1.6k'], dtype=object)

# %%
df['Total Interviews'].unique()
# Out:
# array(['10.7k', '8.4k', '5.8k', '5.7k', '4.9k', '2.3k', '7.7k', '2.5k',
#        '4k', '3.9k', '3.2k', '1.8k', '1.7k', '1.5k', '5.1k', '2k', '675',
#        '1.6k', '2.4k', '3k', '841', '2.9k', '1.1k', '1.3k', '2.1k', '567',
#        '892', '1k', '544', '641', '1.4k', '1.2k', '683', '808', '974',
#        '700', '543', '635', '486', '820', '571', '452', '490', '765',
#        '882', '663', '433', '611', '607', '559', '651', '356', '419',
#        '760', '499', '524', '247', '411', '321', '590', '778', '404',
#        '762', '484', '398', '255', '357', '727', '771', '327', '445',
#        '612', '414', '812', '494', '464', '320', '242', '319', '461',
#        '871', '156', '262', '457', '271', '542', '338', '460', '344',
#        '376', '548', '597', '545', '658', '434', '275', '309', '413',
#        '501', '200', '600', '366', '250', '289', '369', '299', '348',
#        '575', '349', '159', '335', '303', '168', '116', '157', '354',
# ...

# %%
df['Salaries'].unique()
# Out:
# array(['8.9L', '5.9L', '4.5L', '5.7L', '4.4L', '1.4L', '4.8L', '1.5L',
#        '3.4L', '2.7L', '2.1L', '91.5k', '1.2L', '99.5k', '1.3L', '62.2k',
#        '22.8k', '66.9k', '2L', '1.8L', '50k', '69.6k', '1.9L', '82.5k',
#        '68.6k', '58.6k', '53.2k', '46.7k', '63.3k', '41.1k', '26.2k',
#        '49.1k', '49.2k', '44.9k', '74.7k', '67.1k', '37.3k', '27.4k',
#        '93.3k', '31.1k', '27k', '69k', '23.4k', '42.4k', '23.7k', '32.3k',
#        '30.5k', '23k', '29k', '25.3k', '22.6k', '26.3k', '30.8k', '13.7k',
#        '42.2k', '40.4k', '24.5k', '8.4k', '24.4k', '21.4k', '51.1k',
#        '33k', '73.6k', '19.5k', '14.8k', '40.5k', '22.4k', '48.3k',
#        '18.7k', '18.9k', '12.2k', '27.2k', '21.9k', '22.7k', '54.2k',
#        '38k', '48.7k', '18.3k', '12.4k', '14.2k', '20.3k', '57.3k',
#        '9.4k', '14.5k', '16.7k', '29.1k', '17k', '23.3k', '16k', '21.6k',
#        '38.8k', '53.1k', '42k', '19k', '37.5k', '30.9k', '21.5k', '14.9k',
# ...

# %%
df['Total Jobs'].unique()
# Out:
# array(['177', '8.8k', '4.1k', '204', '2k', '529', '2.4k', '22', '227',
#        '712', '461', '380', '137', '202', '2.2k', '116', '216', '119',
#        '1k', '414', '152', '127', '61', '28', '--', '24', '182', '111',
#        '14', '74', '2.9k', '113', '2.1k', '44', '203', '73', '54', '21',
#        '135', '355', '159', '2', '348', '58', '468', '29', '71', '779',
#        '90', '6', '197', '20', '154', '79', '87', '37', '18', '83', '194',
#        '17', '411', '817', '102', '45', '91', '106', '169', '26', '1.1k',
#        '1.2k', '249', '4', '210', '1', '27', '50', '23', '145', '53',
#        '170', '146', '333', '525', '323', '673', '168', '16', '36', '112',
#        '110', '200', '25', '39', '59', '70', '231', '47', '51', '100',
#        '178', '49', '338', '7', '209', '46', '275', '55', '11', '5',
#        '432', '30', '3', '13', '64', '85', '63', '9', '913', '89', '198',
#        '19', '172', '12', '86', '141', '192', '239', '84', '8', '33',
# ...

# %%
df["Company Type"].unique()
# Out:
# array(['IT Services & Consulting', 'Banking', 'BPO', 'Internet',
#        'Telecom', 'Retail', 'NBFC', 'Engineering & Construction',
#        'Management Consulting', 'Oil & Gas', 'EdTech', 'Automobile',
#        'Financial Services', 'Insurance', 'Unknown', 'FinTech',
#        'Iron & Steel', 'Chemicals', 'Building Material',
#        'Consumer Electronics & Appliances', 'Analytics & KPO', 'Pharma',
#        'Logistics', 'FMCG', 'Software Product', 'Defence & Aerospace',
#        'Real Estate', 'Industrial Automation', 'Healthcare',
#        'Clinical Research', 'Auto Components', 'Fashion & Textile',
#        'Beverage', 'Recruitment', 'Hospitality', 'Accounting & Auditing',
#        'Electrical Equipment', 'Industrial Machinery',
#        'Education & Training', 'Media & Entertainment',
#        'Facility Management Services', 'Metals & Mining',
#        'Electronics Manufacturing', 'Non-Profit', 'Agro Chemicals',
# ...

# %%
df.columns
# Out:
# Index(['Title', 'Reviews', 'Ratings', 'Company Type', 'Salaries',
#        'Total Interviews', 'Total Jobs', 'Founded Year', 'Company Age',
#        'Websites'],
#       dtype='object')

# %%
# def dtypeint(df):
#     l = ['Reviews'] #'Salaries', 'Total Interviews', 'Total Jobs', 'Founded Year', 'Company Age']
#     for i in l:
#         #for j in df[i]:
#             #if 'k' in j:
#         df[i] = df[i].replace('k','',regex = True)
#         df[i] = pd.to_numeric(df[i])
#         df[i] = df[i]*1000
#         df[i] = df[i].astype('int')

#     l2 = ['Salaries','Total Interviews','Total Jobs']
#     n=0
#     for i in l2:
#         while n<500:
#             if 'k' in df[i].iloc[n]:
#                 df[i].iloc[n] = df[i].iloc[n].replace('k','')
#             if 'L' in df[i].iloc[n]:
#                 df[i].iloc[n] = df[i].iloc[n].replace('L','')
#             n += 1
                
                
            
            #df[i] = df[i].replace('L','',regex = True)
            #df[i] = df[i].replace('k','',regex = True)
            #df[i] = df[i].replace('--',np.nan)
            #df[i] = pd.to_numeric(df[i])
        






        
                #df[i] = pd.to_numeric(df[i])
                #df[i] = df[i]*1000
        #if 'L' in df[i]:
        #    df[i] = df[i].replace("L","")
        #    df[i] = df[i].astype('int')
        #    df[i] = df[i]*100000
        #df[i] = df[i].astype('int')

# %%
df['Total Jobs'] = df['Total Jobs'].replace('--',np.nan)

# %%
def dtypeint(df):
    l = ['Reviews']                                         #'Salaries', 'Total Interviews', 'Total Jobs', 'Founded Year', 'Company Age']
    for i in l:
        #for j in df[i]:
            #if 'k' in j:
        df[i] = df[i].replace('k','',regex = True)
        df[i] = pd.to_numeric(df[i])
        df[i] = df[i]*1000
        df[i] = df[i].astype('int')

def sal(j):
    if 'k' in j:
        return float(j.replace('k',''))*1000
    elif 'L' in j:
        return float(j.replace('L',''))*100000
    else:
        return float(j)
    
def interv(j):
    if 'k' in j:
        return float(j.replace('k',''))*1000
    elif 'L' in j:
        return float(j.replace('L',''))*100000
    else:
        return float(j)

# %%
df
# Out:
#                            Title Reviews  Ratings  \
# 0                            TCS   93.7k      3.7
# 1                      Accenture   59.3k      3.8
# 2                          Wipro   55.1k      3.7
# 3                      Cognizant   52.4k      3.7
# 4                      Capgemini   43.9k      3.7
# ..                           ...     ...      ...
# 495  Infinite Computer Solutions    1.6k      3.4
# 496                      Philips    1.6k      3.8
# 497              Dr Lal PathLabs    1.6k      4.2
# 498         Honeywell Automation    1.6k      3.8
# 499                Nuvoco Vistas    1.6k      4.1
#
#                           Company Type Salaries Total Interviews Total Jobs  \
# 0             IT Services & Consulting     8.9L            10.7k        177
# 1             IT Services & Consulting     5.9L             8.4k       8.8k
# 2             IT Services & Consulting     4.5L             5.8k       4.1k
# ...

# %%
df["Total Jobs"]
# Out:
# 0       177
# 1      8.8k
# 2      4.1k
# 3       204
# 4        2k
#        ...
# 495     185
# 496     119
# 497      58
# 498       1
# 499      20
# Name: Total Jobs, Length: 500, dtype: object

# %%
def jobs(j):
    if j == np.nan:
        return j
    elif 'k' in str(j):
        a = float(j.replace('k',''))*1000
        return a
    else:
        return float(j)

# %%
df["Total Jobs"] = df["Total Jobs"].apply(jobs)

# %%
#df['Total Jobs'].apply(jobs)

# %%
# def jobs(df):
#     df[i] = df[i].replace('k','',regex= True)
#     df[i] = pd.to_numeric(df[i])
#     df[i].fillna(df[i].median(),inplace = True)

# %%
#jobs(df)

# %%
df['Total Jobs']
# Out:
# 0       177.0
# 1      8800.0
# 2      4100.0
# 3       204.0
# 4      2000.0
#         ...
# 495     185.0
# 496     119.0
# 497      58.0
# 498       1.0
# 499      20.0
# Name: Total Jobs, Length: 500, dtype: float64

# %%
# df['Total Jobs'] = df['Total Jobs'].replace('--',np.nan)

# %%
# df['Total Jobs'] = pd.to_numeric(df['Total Jobs'])
# df['Total Jobs'] = df['Total Jobs'].apply(jobs)
# df['Total Jobs'].fillna(df['Total Jobs'].median(),inplace = True)

# %%
dtypeint(df)
df['Salaries'] = df['Salaries'].apply(sal)
df['Total Interviews'] = df['Total Interviews'].apply(interv)
#df['Total Jobs'] = df['Total Jobs'].apply(jobs)

# %%
df.columns
# Out:
# Index(['Title', 'Reviews', 'Ratings', 'Company Type', 'Salaries',
#        'Total Interviews', 'Total Jobs', 'Founded Year', 'Company Age',
#        'Websites'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             500 non-null    object
#  1   Reviews           500 non-null    int32
#  2   Ratings           500 non-null    float64
#  3   Company Type      478 non-null    object
#  4   Salaries          500 non-null    float64
#  5   Total Interviews  500 non-null    float64
#  6   Total Jobs        442 non-null    float64
#  7   Founded Year      485 non-null    float64
#  8   Company Age       485 non-null    float64
#  9   Websites          500 non-null    object
# dtypes: float64(6), int32(1), object(3)
# memory usage: 37.2+ KB

# %%
def descrete(df):
    l1 = ['Founded Year']
    for i in l1:
        df[i].fillna(value='Not Available',inplace=True)

# %%
descrete(df)
# Out:
# C:\Users\rake0\AppData\Local\Temp\ipykernel_24140\292508839.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[i].fillna(value='Not Available',inplace=True)
# C:\Users\rake0\AppData\Local\Temp\ipykernel_24140\292508839.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Not Available' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df[i].fillna(value='Not Available',inplace=True)

# %%
df[['Founded Year','Company Age']].isna().sum()
# Out:
# Founded Year     0
# Company Age     15
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             500 non-null    object
#  1   Reviews           500 non-null    int32
#  2   Ratings           500 non-null    float64
#  3   Company Type      478 non-null    object
#  4   Salaries          500 non-null    float64
#  5   Total Interviews  500 non-null    float64
#  6   Total Jobs        442 non-null    float64
#  7   Founded Year      500 non-null    object
#  8   Company Age       485 non-null    float64
#  9   Websites          500 non-null    object
# dtypes: float64(5), int32(1), object(4)
# memory usage: 37.2+ KB

# %%
df[df['Total Jobs'].isna()]
# Out:
#                                                 Title  Reviews  Ratings  \
# 25                                             BYJU'S    16300      3.1
# 47                                         Tata Steel     7700      4.1
# 72                                   L&T Construction     6200      4.0
# 86                                        Indian Army     5400      4.7
# 103                                Standard Chartered     4800      3.7
# 116                                          Citicorp     4600      3.7
# 117                                     Hero MotoCorp     4500      4.1
# 139                               State Bank of India     4000      3.8
# 161                           Reliance Communications     3500      4.0
# 164                                        Team Lease     3500      3.9
# 176                       HDFC Ergo General Insurance     3300      3.9
# 200                                Bharat Electronics     3100      4.2
# ...

# %%
df['Total Jobs'].fillna(value=0,inplace=True)
df['Company Age'].fillna(value=0,inplace=True)
# Out:
# C:\Users\rake0\AppData\Local\Temp\ipykernel_24140\4274336270.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Total Jobs'].fillna(value=0,inplace=True)
# C:\Users\rake0\AppData\Local\Temp\ipykernel_24140\4274336270.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['Company Age'].isna().sum()
# Out:
# 0

# %%
def dtypeint2(df):
    l1 = ['Salaries', 'Total Interviews', 'Total Jobs', 'Company Age'] #'Founded Year', 'Company Age'
    for i in l1:
        df[i] = df[i].astype('int')

# %%
dtypeint2(df)

# %%
df
# Out:
#                            Title  Reviews  Ratings  \
# 0                            TCS    93700      3.7
# 1                      Accenture    59300      3.8
# 2                          Wipro    55100      3.7
# 3                      Cognizant    52400      3.7
# 4                      Capgemini    43900      3.7
# ..                           ...      ...      ...
# 495  Infinite Computer Solutions     1600      3.4
# 496                      Philips     1600      3.8
# 497              Dr Lal PathLabs     1600      4.2
# 498         Honeywell Automation     1600      3.8
# 499                Nuvoco Vistas     1600      4.1
#
#                           Company Type  Salaries  Total Interviews  \
# 0             IT Services & Consulting    890000             10700
# 1             IT Services & Consulting    590000              8400
# 2             IT Services & Consulting    450000              5800
# 3             IT Services & Consulting    570000              5700
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             500 non-null    object
#  1   Reviews           500 non-null    int32
#  2   Ratings           500 non-null    float64
#  3   Company Type      478 non-null    object
#  4   Salaries          500 non-null    int32
#  5   Total Interviews  500 non-null    int32
#  6   Total Jobs        500 non-null    int32
#  7   Founded Year      500 non-null    object
#  8   Company Age       500 non-null    int32
#  9   Websites          500 non-null    object
# dtypes: float64(1), int32(5), object(4)
# memory usage: 29.4+ KB

# %%
df[df['Company Type'].isna()]
# Out:
#                                                Title  Reviews  Ratings  \
# 45                                           Startek     7900      3.1
# 83                                   Ekart Logistics     5600      3.9
# 174                         Macleods Pharmaceuticals     3400      3.6
# 210                                Cogent E Services     3000      3.3
# 264                   Amazon Transportation Services     2600      4.2
# 279                               I Process Services     2500      3.9
# 308                                   Domino's Pizza     2300      3.9
# 310                                       XpressBees     2300      3.6
# 321                       TVS Supply Chain Solutions     2200      3.8
# 324                                       McDonald's     2200      4.1
# 341                                Himalaya Wellness     2100      4.1
# 342                   Taj Hotels Resorts and Palaces     2100      4.2
# ...

# %%
df['Company Type'].fillna(value='Unknown',inplace=True)
# Out:
# C:\Users\rake0\AppData\Local\Temp\ipykernel_24140\10851803.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Company Type'].fillna(value='Unknown',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             500 non-null    object
#  1   Reviews           500 non-null    int32
#  2   Ratings           500 non-null    float64
#  3   Company Type      500 non-null    object
#  4   Salaries          500 non-null    int32
#  5   Total Interviews  500 non-null    int32
#  6   Total Jobs        500 non-null    int32
#  7   Founded Year      500 non-null    object
#  8   Company Age       500 non-null    int32
#  9   Websites          500 non-null    object
# dtypes: float64(1), int32(5), object(4)
# memory usage: 29.4+ KB

# %%
df
# Out:
#                            Title  Reviews  Ratings  \
# 0                            TCS    93700      3.7
# 1                      Accenture    59300      3.8
# 2                          Wipro    55100      3.7
# 3                      Cognizant    52400      3.7
# 4                      Capgemini    43900      3.7
# ..                           ...      ...      ...
# 495  Infinite Computer Solutions     1600      3.4
# 496                      Philips     1600      3.8
# 497              Dr Lal PathLabs     1600      4.2
# 498         Honeywell Automation     1600      3.8
# 499                Nuvoco Vistas     1600      4.1
#
#                           Company Type  Salaries  Total Interviews  \
# 0             IT Services & Consulting    890000             10700
# 1             IT Services & Consulting    590000              8400
# 2             IT Services & Consulting    450000              5800
# 3             IT Services & Consulting    570000              5700
# ...

# %%
def regex1(x):
    txt = x.strip()
    reg = re.findall(r"(^.+\.?\w+\.(?:com|org|in|jobs|net|ntt|bank|ai|abb|barclays|run|tech|ee|biz|live|bnpparibas))\s?",txt)
    return reg[0]

# %%
df['Websites'] = df['Websites'].apply(regex1)

# %%
df['Websites']
# Out:
# 0                tcs.com
# 1          accenture.com
# 2      careers.wipro.com
# 3          cognizant.com
# 4          capgemini.com
#              ...
# 495         infinite.com
# 496          philips.com
# 497      lalpathlabs.com
# 498        honeywell.com
# 499           nuvoco.com
# Name: Websites, Length: 500, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             500 non-null    object
#  1   Reviews           500 non-null    int32
#  2   Ratings           500 non-null    float64
#  3   Company Type      500 non-null    object
#  4   Salaries          500 non-null    int32
#  5   Total Interviews  500 non-null    int32
#  6   Total Jobs        500 non-null    int32
#  7   Founded Year      500 non-null    object
#  8   Company Age       500 non-null    int32
#  9   Websites          500 non-null    object
# dtypes: float64(1), int32(5), object(4)
# memory usage: 29.4+ KB

# %%
df.to_csv("Companies_500_Cleaned.csv",index=False)

# %%
# for i in list(df['Websites']):
#     print(i)
#     print()
# Out:
# tcs.com
#
# accenture.com
#
# careers.wipro.com
#
# cognizant.com
#
# capgemini.com
#
# hdfcbank.com
#
# infosys.com
#
# icicibank.com
#
# hcltech.com
#
# techmahindra.com
#
# genpact.com
#
# ...

# %%
# for i in list(df['Websites']):
#     print(i)
#     print()
# Out:
# tcs.com
#
# accenture.com
#
# careers.wipro.com
#
# cognizant.com
#
# capgemini.com
#
# hdfcbank.com
#
# infosys.com
#
# icicibank.com
#
# hcltech.com
#
# techmahindra.com
#
# genpact.com
#
# teleperformance.com
#
# concentrix.com
#
# axisbank.com
#
# amazon.jobs
#
# jio.com
#
# ienergizer.com Company contact no.8588894888 E-mailinfo@iEnergizer.com
#
# relianceretail.com
#
# ibm.com
#
# ltimindtree.com
#
# hdbfs.com
#
# larsentoubro.com
#
# www2.deloitte.com
#
# kotak.com
#
# ril.com
#
# byjus.com
#
# myvi.in
#
# airtel.in
#
# wns.com
#
# tatamotors.com
#
# aubank.in
#
# indusind.com
#
# flipkart.com
#
# ey.com
#
# idfcfirstbank.com
#
# dxc.com
#
# infosysbpm.com
#
# mahindra.com
#
# bajajfinserv.in
#
# pwc.com
#
# hdfclife.com
#
# conneqtcorp.com
#
# mphasis.com
#
# bandhanbank.com
#
# yesbank.in
#
# startek.com
#
# paytm.com
#
# tatasteel.com
#
# asianpaints.com
#
# quesscorp.com
#
# marutisuzuki.com
#
# ultratechcement.com
#
# samsung.com
#
# sutherlandglobal.com
#
# ...

# %%
#        (^\w+\.?\w+?\.\w+)\s?

# %%
#        (^.+\.?\w+\.(?:com|org|in|jobs|net|ntt|bank|ai|abb|barclays|run|tech|ee|biz|live|bnpparibas))\s?   # best one

# %%
'L' in '5.9L'
# Out:
# True

# %%
10.7*1000
# Out:
# 10700.0

# %%
4.5*100000
# Out:
# 450000.0

# %%
93.7*1000
# Out:
# 93700.0

# %%
df['Salaries'][15].replace('k','')
# Out:
# '62.2'

# %%
df['Salaries'].iloc[2].replace('L','')
# Out:
# '4.5'

# %%
l = ["153K","1.4L"]

# %%
for i in l:
    if "K"  in i:
        print(int(i.replace("K","")) *1000)
    else:
        print(float(i.replace("L","")) *100000)
# Out:
# 153000
# 140000.0

# %%
for i in df['Salaries']:
    #print(i)
    n = 0
    if "k" in i:
        df['Salaries'] = int(i.replace("k",""))*1000
# Out:
# 91.5k
# 99.5k
# 62.2k
# 22.8k
# 66.9k
# 50k
# 69.6k
# 82.5k
# 68.6k
# 58.6k
# 53.2k
# 46.7k
# 63.3k
# 41.1k
# 26.2k
# 49.1k
# 49.2k
# 44.9k
# 74.7k
# 67.1k
# 37.3k
# 27.4k
# 93.3k
# 31.1k
# 27k
# 69k
# 23.4k
# 42.4k
# 23.7k
# 32.3k
# 30.5k
# 23k
# 29k
# 25.3k
# 22.6k
# 26.3k
# 30.8k
# 13.7k
# 42.2k
# 40.4k
# 24.5k
# 8.4k
# 22.8k
# 24.4k
# 21.4k
# 51.1k
# 33k
# 21.4k
# 73.6k
# 19.5k
# 21.4k
# 14.8k
# 40.5k
# 22.4k
# 48.3k
# 18.7k
# 18.9k
# 12.2k
# 27.2k
# 21.9k
# 22.7k
# 54.2k
# 38k
# 48.7k
# 18.3k
# 12.4k
# 14.2k
# 20.3k
# 57.3k
# 9.4k
# 14.5k
# 16.7k
# 12.2k
# 29.1k
# 17k
# 23.3k
# 16k
# 21.6k
# 38.8k
# 53.1k
# 42k
# 19k
# 37.5k
# 30.9k
# 21.5k
# 14.9k
# 39.8k
# 22.5k
# 16k
# 43.4k
# 11.4k
# 36.2k
# 15.9k
# 18.1k
# 18.8k
# 17.6k
# 26.4k
# 36.5k
# 36.8k
# 44.9k
# 14.9k
# 11.2k
# 14.7k
# 29.8k
# 13.3k
# 10.6k
# 10.4k
# 8.3k
# 28.8k
# 32k
# 14.9k
# 28.2k
# 21k
# 15.2k
# 27.9k
# 12.3k
# 38.7k
# 12.6k
# 35.7k
# 20.1k
# 17.3k
# 29k
# 11k
# 27k
# 13.4k
# 13.8k
# 11k
# 21.9k
# 27.7k
# ...

# %%
# print(list(df['Total Interviews']))

# %%
# print(list(df['Salaries']))

# %%
df
# Out:
#                            Title Reviews  Ratings  \
# 0                            TCS   93.7k      3.7
# 1                      Accenture   59.3k      3.8
# 2                          Wipro   55.1k      3.7
# 3                      Cognizant   52.4k      3.7
# 4                      Capgemini   43.9k      3.7
# ..                           ...     ...      ...
# 495  Infinite Computer Solutions    1.6k      3.4
# 496                      Philips    1.6k      3.8
# 497              Dr Lal PathLabs    1.6k      4.2
# 498         Honeywell Automation    1.6k      3.8
# 499                Nuvoco Vistas    1.6k      4.1
#
#                           Company Type Salaries Total Interviews Total Jobs  \
# 0             IT Services & Consulting     8.9L            10.7k        177
# 1             IT Services & Consulting     5.9L             8.4k       8.8k
# 2             IT Services & Consulting     4.5L             5.8k       4.1k
# ...

# %%
# df["Total Interviews"].apply(sal)
# Out:
# 0      10700.0
# 1       8400.0
# 2       5800.0
# 3       5700.0
# 4       4900.0
#         ...
# 495      150.0
# 496      160.0
# 497      130.0
# 498      104.0
# 499       99.0
# Name: Total Interviews, Length: 500, dtype: float64

# %%
def sal(j):
    if 'k' in j:
        return float(j.replace('k',''))*1000
    elif 'L' in j:
        return float(j.replace('L',''))*100000
    else:
        return float(j)

# %%
def interv(j):
    if 'k' in j:
        return float(j.replace('k',''))*1000
    elif 'L' in j:
        return float(j.replace('L',''))*100000
    else:
        return float(j)

# %%
def jobs(j):
    if 'k' in j:
        return float(j.replace('k',''))*1000
    # elif 'L' in j:
    #     return float(j.replace('L',''))*100000
    else:
        return float(j)

# %%
sal = [sal(j) for j in list(df['Salaries'])]
tint = [interv(j) for j in list(df['Total Interviews'])]
job = [jobs(j) for j in list(df['Total Jobs'])]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1287], line 3
#       1 sal = [sal(j) for j in list(df['Salaries'])]
#       2 tint = [interv(j) for j in list(df['Total Interviews'])]
# ----> 3 job = [jobs(j) for j in list(df['Total Jobs'])]
#
# Cell In[1285], line 2, in jobs(j)
#       1 def jobs(j):
# ----> 2     if 'k' in j:
#       3         return float(j.replace('k',''))*1000
#       4     # elif 'L' in j:
#       5     #     return float(j.replace('L',''))*100000
#       6     else:
#
# TypeError: argument of type 'float' is not iterable

# %%
df["Total Jobs"].isna().sum()
# Out:
# 58

# %%
sal
# Out:
# [890000.0,
#  590000.0,
#  450000.0,
#  570000.0,
#  440000.00000000006,
#  140000.0,
#  480000.0,
#  150000.0,
#  340000.0,
#  270000.0,
#  210000.0,
#  91500.0,
#  120000.0,
#  99500.0,
#  130000.0,
#  62200.0,
#  22800.0,
#  66900.0,
#  200000.0,
#  180000.0,
#  50000.0,
#  69600.0,
#  190000.0,
#  82500.0,
#  68600.0,
#  58600.0,
#  53200.0,
#  46700.0,
#  63300.0,
#  41100.0,
#  26200.0,
#  49100.0,
#  49200.0,
#  120000.0,
#  44900.0,
#  74700.0,
#  67100.0,
#  37300.0,
#  27400.0,
#  93300.0,
#  31100.0,
#  27000.0,
#  69000.0,
#  23400.0,
#  42400.0,
#  23700.0,
#  32299.999999999996,
#  30500.0,
#  23000.0,
#  29000.0,
#  25300.0,
#  22600.0,
#  26300.0,
#  30800.0,
#  13700.0,
#  42200.0,
#  40400.0,
#  24500.0,
#  8400.0,
#  22800.0,
#  24400.0,
#  21400.0,
#  51100.0,
#  33000.0,
#  21400.0,
#  73600.0,
#  19500.0,
#  21400.0,
#  14800.0,
#  40500.0,
#  22400.0,
#  48300.0,
#  18700.0,
#  18900.0,
#  12200.0,
#  27200.0,
#  21900.0,
#  22700.0,
#  54200.0,
#  38000.0,
# ...

# %%
tint
# Out:
# [10700.0,
#  8400.0,
#  5800.0,
#  5700.0,
#  4900.0,
#  2300.0,
#  7700.0,
#  2500.0,
#  4000.0,
#  3900.0,
#  3200.0,
#  1800.0,
#  1700.0,
#  1500.0,
#  5100.0,
#  2000.0,
#  675.0,
#  1600.0,
#  2400.0,
#  3000.0,
#  841.0,
#  1500.0,
#  2900.0,
#  1100.0,
#  1300.0,
#  2100.0,
#  567.0,
#  892.0,
#  1100.0,
#  1000.0,
#  544.0,
#  641.0,
#  1400.0,
#  1200.0,
#  683.0,
#  808.0,
#  974.0,
#  700.0,
#  543.0,
#  1400.0,
#  635.0,
#  486.0,
#  820.0,
#  571.0,
#  452.0,
#  490.0,
#  765.0,
#  882.0,
#  663.0,
#  433.0,
#  611.0,
#  607.0,
#  559.0,
#  651.0,
#  356.0,
#  419.0,
#  760.0,
#  499.0,
#  524.0,
#  247.0,
#  411.0,
#  321.0,
#  590.0,
#  778.0,
#  404.0,
#  762.0,
#  484.0,
#  398.0,
#  255.0,
#  635.0,
#  357.0,
#  727.0,
#  771.0,
#  327.0,
#  445.0,
#  612.0,
#  414.0,
#  571.0,
#  812.0,
#  494.0,
#  464.0,
#  320.0,
#  242.0,
#  319.0,
#  461.0,
#  871.0,
#  156.0,
#  262.0,
#  457.0,
#  271.0,
#  542.0,
#  338.0,
#  460.0,
#  344.0,
#  376.0,
#  548.0,
#  597.0,
# ...

# %%
job
# Out:
# [450000.0, 5800.0, 4100.0]

# %%
df['Salaries'] = df['Salaries'].replace('k','',regex = True).as

# %%
for j in df['Reviews']
if 'k' in df['Reviews'][0]:
    print(True)
# Out:
# True

# %%
# for j in df['Reviews']:
#     print(j)
